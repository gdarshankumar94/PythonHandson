# %%
#Importing Library
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn

# %%
#Data Loading

file = pd.read_csv('setone.csv')
file.head()
# Out:
#        Date Recovered Cumulative recovered  \
# 0  1/3/2020         0                   22
# 1  2/3/2020         0                   22
# 2  3/3/2020         0                   22
# 3  4/3/2020         0                   22
# 4  5/3/2020         0                   22
#
#    Cumulative recovered  (% of all cases) New case Cumulative cases  \
# 0                                   75.86        4               29
# 1                                   75.86        0               29
# 2                                   61.11        7               36
# 3                                   44.00       14               50
# 4                                   40.00        5               55
#
#   Active case Local case Local case (Citizen) Local case (Non-citizen)  ...  \
# 0           7        NaN                  NaN                      NaN  ...
# 1           7        NaN                  NaN                      NaN  ...
# ...

# %%
file.describe()
# Out:
#        Cumulative recovered  (% of all cases)  Imported case  \
# count                              507.000000     332.000000
# mean                                80.297436       7.632530
# std                                 20.136223       8.381963
# min                                  7.280000       0.000000
# 25%                                 75.900000       3.000000
# 50%                                 85.700000       5.000000
# 75%                                 93.975000       9.000000
# max                                 97.900000      72.000000
#
#        Imported case (Citizen)  Imported case (Non-citizen)       Death  \
# count               261.000000                   255.000000  507.000000
# mean                  3.701149                     4.160784   14.282051
# std                   5.457067                     4.117567   28.093740
# min                   0.000000                     0.000000    0.000000
# ...

# %%
file.shape
# Out:
# (507, 28)

# %%
file.isnull().sum()
# Out:
# Date                                         0
# Recovered                                    0
# Cumulative recovered                         0
# Cumulative recovered  (% of all cases)       0
# New case                                     0
# Cumulative cases                             0
# Active case                                  0
# Local case                                 180
# Local case (Citizen)                       251
# Local case (Non-citizen)                   252
# Imported case                              175
# Imported case (Citizen)                    246
# Imported case (Non-citizen)                252
# Death                                        0
# Death (Citizen)                            206
# Death (Non-citizen)                        206
# Cumulative deaths                            0
# Cumulative deaths (% of all cases)           0
# ICU                                          0
# Intubated                                    0
# ...

# %%
DF = pd.DataFrame(file)

sns.boxplot(DF['New case'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1828\2247720567.py in <module>
#       1 DF = pd.DataFrame(file)
#       2
# ----> 3 sns.boxplot(DF['New case'])
#       4
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...
